# %%
import requests
from bs4 import BeautifulSoup
import openpyxl
import pandas as pd

# %%
job=[]

# %%
for i in range(1,11):
    url=f'https://www.timesjobs.com/candidate/job-search.html?from=submit&luceneResultSize=25&txtKeywords=0DQT0data%20analyst0DQT0&postWeek=60&searchType=personalizedSearch&actualTxtKeywords=Data%20Analyst&searchBy=0&rdoOperator=OR&pDate=I&sequence={i}&startPage=1'
    source=requests.get(url)
    soup=BeautifulSoup(source.text,'lxml')
    tags=soup.find_all('li',class_="clearfix job-bx wht-shd-bx")
    
    for tag in tags:
        company_name=tag.find('h3',class_="joblist-comp-name").text.rstrip().lstrip().replace('(More Jobs)','')
        skills=tag.find('span',class_="srp-skills").text.rstrip().lstrip()
        exp=tag.find('ul',class_="top-jd-dtl clearfix").text[12:21]
        loc=tag.span.text.replace('(More Jobs)','')
        link=tag.h2.a['href']
        print(company_name,skills,exp,loc,link)
        job.append([company_name,skills,exp,loc,link])
        sheet.append([company_name,skills,exp,loc,link])
# Out:
# Information Services Group data analysis  ,   python  ,   excel  ,   sql  ,   communication skills   ,  bi  ,  data extraction  ,  database  ,  git  ,  technical skills  ,  machine learning  ,  infrastructure  ,  data communication 2 - 3 yrs Bengaluru / Bangalore https://www.timesjobs.com/job-detail/data-analyst-associate-data-analyst-data-analyst-information-services-group-bengaluru-bangalore-2-to-3-yrs-jobid-tFjUvgIXFkdzpSvf__PLUS__uAgZw==&source=srp
# Zoxima Solutions Pvt. Ltd. reports  ,  Data Analysts  ,  MySQL 3 - 8 yrs  https://www.timesjobs.com/job-detail/data-analysts-zoxima-solutions-pvt-ltd-3-to-8-yrs-jobid-ykoXKM9SnchzpSvf__PLUS__uAgZw==&source=srp
# RDA Labs bi  ,  dashboards  ,  data analyst  ,  impact analysis  ,  analyst 1 - 3 yrs Bengaluru / Bangalore https://www.timesjobs.com/job-detail/data-analyst-rda-labs-bengaluru-bangalore-1-to-3-yrs-jobid-IC1XfaBmtthzpSvf__PLUS__uAgZw==&source=srp
# Best Infosystems Ltd.
# ...

# %%
df=pd.DataFrame(job,columns=(['Company_Name','Skills','Experience','Location','Link']))

# %%
df.head(25)
# Out:
#                                Company_Name  \
# 0                Information Services Group
# 1                Zoxima Solutions Pvt. Ltd.
# 2                                  RDA Labs
# 3            Best Infosystems Ltd.\r\n
# 4                      the modern dimension
# 5      ADROIT LEARNING AND MANPOWER PVT LTD
# 6                       HyreFox Consultants
# 7                                   Uscreen
# 8                     cibirix digital media
# 9                        Brainvire Infotech
# 10        Principal Financial Services Inc.
# 11               Canvas Facilities\r\n
# 12               Canvas Facilities\r\n
# 13                                  Edifecs
# 14                                  Edifecs
# 15                            Ipseity Group
# 16  advanced risk analytics private limited
# 17                            myglamm popxo
# 18                Travel Centric Technology
# 19                                 Hexanika
# 20          BUSISOL SOURCING INDIA PVT. LTD
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 245    False
# 246    False
# 247    False
# 248    False
# 249    False
# Length: 250, dtype: bool

# %%
#To save the datasets into csv file
df.to_csv('TimesJob.csv')

# %%
excel=openpyxl.Workbook()
sheet=excel.active
sheet.title=("TimesJobs")
sheet.append(['Company_Name','Skills','Experience','Location','Link'])

# %%
excel.save("TimesJob.xlsx")
